# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import os
import statistics

# %%
Dataframe_no_kinematics_no_zeros_paired = pd.read_csv('Dataframe_no_kinematics_no_zeros_paired.csv')

# %%
pd.set_option('display.max_columns', None)
Dataframe_no_kinematics_no_zeros_paired.head(-1)
# Out:
#          Unnamed: 0         P1         P2        P3         P4        P5  \
# 0   M_DR_L002M1NAAA  62.939427  37.060573  0.808100  46.982558  1.290000
# 1   M_DR_L002M2NAAA  57.795502  42.204498  1.170233  68.036822  1.158333
# 2   M_DR_L022M1NAAA  66.656806  33.343194  0.793240  45.328000  1.258333
# 3   M_DR_L031M1NAAA  66.041667  33.958333  0.871083  54.785115  1.380000
# 4   M_DR_L031M3NAAA  68.096133  31.903867  1.048997  66.392194  1.138333
# ..              ...        ...        ...       ...        ...       ...
# 94  M_IZ_L356M1NAAA  66.600335  33.399665  0.800827  67.885728  0.993333
# 95  M_IZ_L357M1NAAA  68.263874  31.736126  1.334787  85.563248  1.240000
# 96  M_DR_L035M3NAAA  65.365372  34.634628  0.978843  63.151183  1.045000
# 97  M_DR_L374M1NAAA  75.097029  24.902971  0.653053  42.132473  1.716667
# 98  M_IZ_L035M3NAAA  69.040261  30.959739  1.003367  64.733333  1.038333
#
#            P6        P7         P8        P9        P10       P11         P12  \
# ...

# %%
Dataframe_no_kinematics_no_zeros_paired = Dataframe_no_kinematics_no_zeros_paired.rename(columns = {"Unnamed: 0" :  "Patients"} )

# %%
pd.set_option('display.max_columns', None)
Dataframe_no_kinematics_no_zeros_paired.head(-1)
# Out:
#            Patients         P1         P2        P3         P4        P5  \
# 0   M_DR_L002M1NAAA  62.939427  37.060573  0.808100  46.982558  1.290000
# 1   M_DR_L002M2NAAA  57.795502  42.204498  1.170233  68.036822  1.158333
# 2   M_DR_L022M1NAAA  66.656806  33.343194  0.793240  45.328000  1.258333
# 3   M_DR_L031M1NAAA  66.041667  33.958333  0.871083  54.785115  1.380000
# 4   M_DR_L031M3NAAA  68.096133  31.903867  1.048997  66.392194  1.138333
# ..              ...        ...        ...       ...        ...       ...
# 94  M_IZ_L356M1NAAA  66.600335  33.399665  0.800827  67.885728  0.993333
# 95  M_IZ_L357M1NAAA  68.263874  31.736126  1.334787  85.563248  1.240000
# 96  M_DR_L035M3NAAA  65.365372  34.634628  0.978843  63.151183  1.045000
# 97  M_DR_L374M1NAAA  75.097029  24.902971  0.653053  42.132473  1.716667
# 98  M_IZ_L035M3NAAA  69.040261  30.959739  1.003367  64.733333  1.038333
#
#            P6        P7         P8        P9        P10       P11         P12  \
# ...

# %%
Dataframe_no_kinematics_no_zeros_paired = Dataframe_no_kinematics_no_zeros_paired.set_index('Patients')

# %%
pd.set_option('display.max_columns', None)
Dataframe_no_kinematics_no_zeros_paired.head(-1)
# Out:
#                         P1         P2        P3         P4        P5  \
# Patients
# M_DR_L002M1NAAA  62.939427  37.060573  0.808100  46.982558  1.290000
# M_DR_L002M2NAAA  57.795502  42.204498  1.170233  68.036822  1.158333
# M_DR_L022M1NAAA  66.656806  33.343194  0.793240  45.328000  1.258333
# M_DR_L031M1NAAA  66.041667  33.958333  0.871083  54.785115  1.380000
# M_DR_L031M3NAAA  68.096133  31.903867  1.048997  66.392194  1.138333
# ...                    ...        ...       ...        ...       ...
# M_IZ_L356M1NAAA  66.600335  33.399665  0.800827  67.885728  0.993333
# M_IZ_L357M1NAAA  68.263874  31.736126  1.334787  85.563248  1.240000
# M_DR_L035M3NAAA  65.365372  34.634628  0.978843  63.151183  1.045000
# M_DR_L374M1NAAA  75.097029  24.902971  0.653053  42.132473  1.716667
# M_IZ_L035M3NAAA  69.040261  30.959739  1.003367  64.733333  1.038333
#
#                         P6        P7         P8        P9        P10  \
# Patients
# ...

# %%
print(len(Dataframe_no_kinematics_no_zeros_paired.index))
# Out:
# 100

# %% [markdown]
# ## Pairing cycles of patients

# %%
indexes_comparing = []
for i in range(0,len(Dataframe_no_kinematics_no_zeros_paired.index)) :
    indexes_comparing.append(Dataframe_no_kinematics_no_zeros_paired.index[i])
print(len(indexes_comparing))

pairs = []
for i in indexes_comparing:
    if i[2:4] == 'DR':
        if i.replace("DR", "IZ") in indexes_comparing:
            pairs.append((i,i.replace("DR", "IZ")))
        else:
             print(i, 'Has not its contralateral limb') 
                
print(len(pairs))
print(len(pairs[0]))
print(pairs)
# Out:
# 100
# 50
# 2
# ...

# %%
Dataframe_no_kinematics_no_zeros_paired_sorted = pd.DataFrame(index = index_sorted, columns =  Dataframe_no_kinematics_no_zeros_paired.columns)

# %%
Dataframe_no_kinematics_no_zeros_paired_sorted.head(-1)
# Out:
#                   P1   P2   P3   P4   P5   P6   P7   P8   P9  P10  P11  P12  \
# M_DR_L002M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_IZ_L002M2NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_DR_L002M2NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_IZ_L022M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_DR_L022M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...              ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# M_DR_L357M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_DR_L035M3NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_IZ_L002M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_DR_L374M1NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# M_IZ_L002M2NAAA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
for i in range(0,len(index_sorted)):
    Dataframe_no_kinematics_no_zeros_paired_sorted.iloc[i] = Dataframe_no_kinematics_no_zeros_paired.loc[index_sorted[i]]

# %% [markdown]
# Lo redondea pero son los mismos valores for each column

# %%
Dataframe_no_kinematics_no_zeros_paired_sorted.head(3)
# Out:
#                       P1       P2       P3       P4       P5       P6  \
# M_DR_L002M1NAAA  62.9394  37.0606   0.8081  46.9826     1.29  46.5653
# M_IZ_L002M2NAAA  62.6156  37.3844  1.11675  64.9275    1.185  50.6589
# M_DR_L002M2NAAA  57.7955  42.2045  1.17023  68.0368  1.15833  51.8849
#
#                        P7       P8        P9      P10       P11      P12  \
# M_DR_L002M1NAAA   0.62829  36.5285   0.38712   22.507     0.665  90.2703
# M_IZ_L002M2NAAA  0.942554  54.7997  0.585027  34.0132      0.61   98.374
# M_DR_L002M2NAAA   1.01178  58.8241  0.545543  31.7176  0.578333  103.933
#
#                       P13       P14      HV1      HV2      KV1      KV2  \
# M_DR_L002M1NAAA      0.42  0.203333 -50.4268   48.578  35.9416 -29.9792
# M_IZ_L002M2NAAA  0.488333      0.09  -89.992  87.0768   163.87 -98.3021
# M_DR_L002M2NAAA  0.443333  0.166667 -80.7528  87.2817  104.921 -41.1429
#
#                      AV1    Vfdt1    Vfdt2      HR1      HR2      HR3  \
# ...

# %%
Dataframe_no_kinematics_no_zeros_paired.head(2)
# Out:
#                         P1         P2        P3         P4        P5  \
# Patients
# M_DR_L002M1NAAA  62.939427  37.060573  0.808100  46.982558  1.290000
# M_DR_L002M2NAAA  57.795502  42.204498  1.170233  68.036822  1.158333
#
#                         P6        P7         P8        P9        P10  \
# Patients
# M_DR_L002M1NAAA  46.565346  0.628290  36.528477  0.387120  22.506977
# M_DR_L002M2NAAA  51.884896  1.011775  58.824138  0.545543  31.717636
#
#                       P11         P12       P13       P14        HV1  \
# Patients
# M_DR_L002M1NAAA  0.665000   90.270263  0.420000  0.203333 -50.426812
# M_DR_L002M2NAAA  0.578333  103.933130  0.443333  0.166667 -80.752790
#
#                        HV2         KV1        KV2        AV1      Vfdt1  \
# Patients
# M_DR_L002M1NAAA  48.577973   35.941583 -29.979234 -52.914337  20.556150
# M_DR_L002M2NAAA  87.281707  104.920805 -41.142917 -79.064595   9.458853
#
#                      Vfdt2        HR1       HR2       HR3       THR1  \
# ...

# %% [markdown]
# # Display all columns and rows

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
Dataframe_no_kinematics_no_zeros_paired_sorted.head(100)
# Out:
#                       P1       P2        P3       P4        P5       P6  \
# M_DR_L002M1NAAA  62.9394  37.0606    0.8081  46.9826      1.29  46.5653
# M_IZ_L002M2NAAA  62.6156  37.3844   1.11675  64.9275     1.185  50.6589
# M_DR_L002M2NAAA  57.7955  42.2045   1.17023  68.0368   1.15833  51.8849
# M_IZ_L022M1NAAA  66.1832  33.8168  0.824777  47.1301      1.29  46.5344
# M_DR_L022M1NAAA  66.6568  33.3432   0.79324   45.328   1.25833  47.7191
# M_IZ_L031M1NAAA  66.1905  33.8095  0.862197  54.2262   1.35833  44.2242
# M_DR_L031M1NAAA  66.0417  33.9583  0.871083  54.7851      1.38  43.5185
# M_IZ_L031M3NAAA  67.7231  32.2769   1.09773  69.4768   1.14667  52.3365
# M_DR_L031M3NAAA  68.0961  31.9039     1.049  66.3922   1.13833  52.7521
# M_IZ_L034M1NAAA  60.9635  39.0365   1.62094  91.0804   1.05833  56.6999
# M_DR_L034M1NAAA  57.5688  42.4312   1.59971   89.887      1.08  55.6065
# M_IZ_L035M1NAAA  60.0347  39.9653   0.97567  65.9236  0.993333  60.8354
# ...

# %%
print(Dataframe_no_kinematics_no_zeros_paired_sorted.index)
# Out:
# Index(['M_DR_L002M1NAAA', 'M_IZ_L002M2NAAA', 'M_DR_L002M2NAAA',
#        'M_IZ_L022M1NAAA', 'M_DR_L022M1NAAA', 'M_IZ_L031M1NAAA',
#        'M_DR_L031M1NAAA', 'M_IZ_L031M3NAAA', 'M_DR_L031M3NAAA',
#        'M_IZ_L034M1NAAA', 'M_DR_L034M1NAAA', 'M_IZ_L035M1NAAA',
#        'M_DR_L035M1NAAA', 'M_IZ_L036M1NAAA', 'M_DR_L036M1NAAA',
#        'M_IZ_L038M1NAAA', 'M_DR_L038M1NAAA', 'M_IZ_L040M1NAAA',
#        'M_DR_L040M1NAAA', 'M_IZ_L041M1NAAA', 'M_DR_L041M1NAAA',
#        'M_IZ_L043M2NAAA', 'M_DR_L043M2NAAA', 'M_IZ_L043M3NAAA',
#        'M_DR_L043M3NAAA', 'M_IZ_L050M1NAAA', 'M_DR_L050M1NAAA',
#        'M_IZ_L052M2NAAA', 'M_DR_L052M2NAAA', 'M_IZ_L059M1NAAA',
#        'M_DR_L059M1NAAA', 'M_IZ_L060M1NAAA', 'M_DR_L060M1NAAA',
#        'M_IZ_L076M3NAAA', 'M_DR_L076M3NAAA', 'M_IZ_L077M1NAAA',
#        'M_DR_L077M1NAAA', 'M_IZ_L080M1NAAA', 'M_DR_L080M1NAAA',
#        'M_IZ_L085M2NAAA', 'M_DR_L085M2NAAA', 'M_IZ_L091M2NAAA',
#        'M_DR_L091M2NAAA', 'M_IZ_L139M1NAAA', 'M_DR_L139M1NAAA',
# ...

# %% [markdown]
# ### Saving as csv . . .

# %%
#Dataframe_no_kinematics_no_zeros_paired_sorted.to_csv(r'C:\Users\riul0\Desktop\TFG_Empresa\Dataframes_to_analyze\Dataframe_no_kinematics_no_zeros_paired_sorted.csv')
